# %%
import re
from darts import TimeSeries
from process_data import process_file_to_dataframe

df = process_file_to_dataframe('data.txt')

series = TimeSeries.from_dataframe(
    df,
    "it",
    ["data0", "data1", "data2", "data3", "data4", "data5"],
)

series.plot()
# Out:
# <Axes: xlabel='it'>
